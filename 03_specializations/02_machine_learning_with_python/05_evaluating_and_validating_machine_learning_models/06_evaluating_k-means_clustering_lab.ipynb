# %% [markdown]
# # Lab: Evaluating K-means Clustering
#
# ---
#
# In this lab we'll learn how to implement and evaluate the performance of k-means clustering on synthetic data. We'll interpret various evaluation metrics and visualizations, and compare clustering results against known classes using synthetic data.
#
# Let's get started by importing the necessary libraries and generating synthetic data for clustering.
